# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
T = np.linspace(50, 500, 100)

# %%
c = 4.02 - 1.839 * T * 10 ** (-3) + T ** 2 * 3.071 * 10 ** (-5) - T ** 3 * 3.549 * 10 ** (-8)

# %%
# グラフの作成
plt.plot(T, c)
plt.xlabel('T')
plt.ylabel('c')
plt.title('c vs T')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp

# Tの範囲を指定
T = np.linspace(50, 500, 100)

# Tをシンボルとして定義
T_sym = sp.Symbol('T')

c = 4.02 - 1.839 * T * 10 ** (-3) + 3.071 * 10 ** (-5) * T ** 2  - 3.549 * 10 ** (-8) * T ** 3 

# 式を定義
c_sub = 4.02 - 1.839 * T_sym * 10 ** (-3) + T_sym ** 2 * 3.071 * 10 ** (-5) - 3.549 * 10 ** (-8) * T_sym ** 3

# Tで微分
derivative = sp.diff(c_sub, T_sym)

# 数値に変換してUを計算
U = []
for t in T:
    c_val = c_sub.subs(T_sym, t).evalf()
    derivative_val = derivative.subs(T_sym, t).evalf()
    u_val = c_val / (1 + (t / c_val) * derivative_val)
    U.append(u_val)

    
#グラフを作成
plt.plot(T, c, label='phase')
plt.plot(T, U, label='group')
plt.xlabel('T')
plt.ylabel('Velocity')
plt.title('c and U vs T')
plt.legend()
plt.grid(True)
plt.show()

# %%
#cosの単純な合成波を書く
import numpy as np
import matplotlib.pyplot as plt

# 周波数範囲と周波数間隔の設定
start_freq = 0.002  # 開始周波数
end_freq = 0.02  # 終了周波数
freq_step = 0.0002  # 周波数間隔
freqs = np.arange(start_freq, end_freq, freq_step)

# 時間軸の設定
duration = 5400  # 時間の長さ（秒）
t = np.arange(0, duration, 5)  # 時間軸

synthetic_cos_wave_0degree = 0
for i in range(len(freqs)):
    synthetic_cos_wave_0degree += np.cos(2 * np.pi * freqs[i] * t)
    
plt.plot(t, synthetic_cos_wave_0degree)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Sum of Cosine Functions at 0 distance')
plt.grid(True)
plt.xticks(range(0, 6000, 500))
plt.show()

# %%
#cosの単純な合成波を書く 　30度違い
import numpy as np
import matplotlib.pyplot as plt

# 周波数範囲と周波数間隔の設定
start_freq = 0.002  # 開始周波数
end_freq = 0.02  # 終了周波数
freq_step = 0.0002  # 周波数間隔
freqs = np.arange(start_freq, end_freq, freq_step)

# 時間軸の設定
duration = 5400  # 時間の長さ（秒）
t = np.arange(0, duration, 5)  # 時間軸

#x = 2 * np.pi * 12800 /12
x = 111.19 * 30

synthetic_cos_wave_30degree = 0
for i in range(len(freqs)):
    c = 4.02 - 1.839 * (1/freqs[i]) * 10 ** (-3) + (1/freqs[i]) ** 2 * 3.071 * 10 ** (-5) -  3.549 * 10 ** (-8) * (1/freqs[i]) ** 3
    synthetic_cos_wave_30degree += np.cos(2*np.pi *  freqs[i] * (x/c - t))
    
plt.plot(t, synthetic_cos_wave_30degree)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Sum of Cosine Functions at 30 degree distance')
plt.grid(True)
plt.xticks(range(0, 6000, 500))
plt.show()

# %%
#cosの単純な合成波を書く 　90度違い
import numpy as np
import matplotlib.pyplot as plt

# 周波数範囲と周波数間隔の設定
start_freq = 0.002  # 開始周波数
end_freq = 0.02  # 終了周波数
freq_step = 0.0002  # 周波数間隔
freqs = np.arange(start_freq, end_freq, freq_step)

# 時間軸の設定
duration = 5400  # 時間の長さ（秒）
t = np.arange(0, duration, 5)  # 時間軸

#x = 2 * np.pi * 12800 /4
x = 111.19 * 90

synthetic_cos_wave_90degree = 0
for i in range(len(freqs)):
    c = 4.02 - 1.839 * (1/freqs[i])* 10 ** (-3) + (1/freqs[i]) ** 2 * 3.071 * 10 ** (-5) - (1/freqs[i]) ** 3 * 3.549 * 10 ** (-8)
    synthetic_cos_wave_90degree += np.cos(2*np.pi *  freqs[i] * (x/c - t))
    
plt.plot(t, synthetic_cos_wave_90degree)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Sum of Cosine Functions at 90 degree distance')
plt.grid(True)
plt.show()

# %%
#cosの単純な合成波を書く 　150度違い
import numpy as np
import matplotlib.pyplot as plt

# 周波数範囲と周波数間隔の設定
start_freq = 0.002  # 開始周波数
end_freq = 0.02  # 終了周波数
freq_step = 0.0002  # 周波数間隔
freqs = np.arange(start_freq, end_freq, freq_step)

# 時間軸の設定
duration = 5400  # 時間の長さ（秒）
t = np.arange(0, duration, 5)  # 時間軸

#x = 2 * np.pi * 12800 * 5 / 12
x = 111.19 * 150

synthetic_cos_wave_150degree = 0
for i in range(len(freqs)): #len(freqs)
    c = 4.02 - 1.839 * (1/freqs[i])* 10 ** (-3) + (1/freqs[i]) ** 2 * 3.071 * 10 ** (-5) - (1/freqs[i]) ** 3 * 3.549 * 10 ** (-8)
    synthetic_cos_wave_150degree += np.cos(2*np.pi * freqs[i] * (x/c - t))
    

plt.plot(t, synthetic_cos_wave_150degree)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Sum of Cosine Functions at 150 degree distance')
plt.grid(True)
plt.xticks(range(0, 6000, 500))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import hilbert

# 周波数範囲と周波数間隔の設定
start_freq = 0.002  # 開始周波数
end_freq = 0.02  # 終了周波数
freq_step = 0.0002  # 周波数間隔
freqs = np.arange(start_freq, end_freq, freq_step)

# 時間軸の設定
duration = 5400  # 時間の長さ（秒）
t = np.arange(0, duration, 5)  # 時間軸

#x = 2 * np.pi * 12800 * 5 / 12
x = 111.19 * 150

synthetic_cos_wave_150degree = 0
for i in range(len(freqs)):
    c = 4.02 - 1.839 * (1/freqs[i])* 10 ** (-3) + (1/freqs[i]) ** 2 * 3.071 * 10 ** (-5) - (1/freqs[i]) ** 3 * 3.549 * 10 ** (-8)
    synthetic_cos_wave_150degree += np.cos(2*np.pi * freqs[i] * (x/c - t))

# 包絡線の計算
analytic_signal = hilbert(synthetic_cos_wave_150degree)
envelope = np.abs(analytic_signal)

# グラフの描画
plt.plot(t, synthetic_cos_wave_150degree, label='Signal')
plt.plot(t, envelope, label='Envelope', color='red')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Envelope Plot using Hilbert Transform')
plt.legend()
plt.grid(True)
plt.xticks(range(0, 6000, 500))
plt.show()

# %%
#cosの単純な合成波を書く 　150度違い
import numpy as np
import matplotlib.pyplot as plt

# 周波数範囲と周波数間隔の設定
start_freq = 0.002  # 開始周波数
end_freq = 0.02  # 終了周波数
freq_step = 0.0002  # 周波数間隔
freqs = np.arange(start_freq, end_freq, freq_step)

# 時間軸の設定
duration = 5400  # 時間の長さ（秒）
t = np.arange(0, duration, 5)  # 時間軸

#x = 2 * np.pi * 12800 * 5 / 12
x = 111.19 * 150

synthetic_cos_wave_hann = 0
for i in range(len(freqs)): #len(freqs)
    c = 4.02 - 1.839 * (1/freqs[i])* 10 ** (-3) + (1/freqs[i]) ** 2 * 3.071 * 10 ** (-5) - (1/freqs[i]) ** 3 * 3.549 * 10 ** (-8)
    synthetic_cos_wave_hann += np.cos(2*np.pi * freqs[i] * (x/c - t))*np.sin(np.pi*(freqs[i] - 0.002)/(0.02- 0.002))**2
    

plt.plot(t, synthetic_cos_wave_hann)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Sum of Cosine Functions at 150 degree distance with hanning taper')
plt.grid(True)
#plt.yticks(range(-40, 40, 10))
plt.xticks(range(0, 6000, 500))
plt.show()

# %%
# グラフの描画
plt.plot(t, synthetic_cos_wave_30degree)
plt.plot(t, synthetic_cos_wave_90degree)
plt.plot(t, synthetic_cos_wave_150degree)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Sum of Cosine Functions at all degree distance')
plt.grid(True)
plt.xticks(range(0, 6000, 500))
plt.show()

# %%
# グラフの描画
plt.plot(t, synthetic_cos_wave_150degree)
plt.plot(t, synthetic_cos_wave_hann)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title(' synthetic_cos_wave at 150 degree distance: with hanning taper and row wave')
plt.grid(True)
plt.xticks(range(0, 6000, 500))
plt.show()

# %%
dis_150degree = 111.19 * 150
dis_90degree = 111.19 * 90
dis_30degree  = 111.19 * 30

# %%
dis = dis_150degree - dis_90degree
dis / 5.4
# Out:
# 1235.4444444444443

# %%
#グラフから、1500秒強で来ているので、合理的?

# %%
import numpy as np
import matplotlib.pyplot as plt

# パラメータ設定
A = 1           # 振幅
c_base = 2      # 基本波速度
delta_c = 0.1   # 波速度の差
x = np.linspace(0, 50, 500) # x軸（距離）

# 8つの波動を合成
num_waves = 8

# 時間ステップと色
time_steps = [0, 20, 40]
colors = ['g', 'b', 'r', 'm']

# c（波速度）を変化させる
c_values = [2, 3, 4, 5]

plt.figure()

for c in c_values:
    y_total = np.zeros_like(x)
    for i in range(num_waves):
        c_i = c + i * delta_c
        y = A * np.sin(time_steps[-1] - x / c_i)
        y_total += y
    
    plt.plot(x, y_total, label=f"c = {c}")

plt.title("Effect of Changing c on Group Velocity")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# パラメータ設定
A = 1           # 振幅
c = 2           # 波速度
x = np.linspace(0, 50, 500) # x軸（距離）

# 8つの波動を合成
num_waves = 8

# 時間ステップと色
time_steps = [0, 20, 40]
colors = ['g', 'b', 'r', 'm']

plt.figure()

for t, color in zip(time_steps, colors):
    y_total = np.zeros_like(x)
    for i in range(num_waves):
        y = A * np.sin(t - x / c)
        y_total += y
    
    plt.plot(x, y_total, label=f"Time = {t}", color=color)

plt.title("Total Waves at Different Times")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# パラメータ設定
A = 1           # 振幅
c = 4          # 波速度
x = np.linspace(0, 50, 500) # x軸（距離）

# 8つの波動を合成
num_waves = 8

# 時間ステップと色
time_steps = [0, 20, 40]
colors = ['g', 'b', 'r', 'm']

plt.figure()

for t, color in zip(time_steps, colors):
    y_total = np.zeros_like(x)
    for i in range(num_waves):
        y = A * np.sin(t - x / c)
        y_total += y
    
    plt.plot(x, y_total, label=f"Time = {t}", color=color)

plt.title("Total Waves at Different Times")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# パラメータ設定
A = 1            # 振幅
c_base = 5       # 基本波速度
delta_c = 0.5    # 波速度の差
x = np.linspace(0, 50, 500) # x軸（距離）

# 8つの波動を合成
num_waves = 8

# 時間ステップと色
time_steps = [0, 2.5, 5, 7.5]
colors = ['g', 'b', 'r', 'm']

plt.figure()

for t, color in zip(time_steps, colors):
    y_total = np.zeros_like(x)
    for i in range(num_waves):
        c_i = c_base + i * delta_c
        y = A * np.sin((t - x / c_i))
        y_total += y
    
    plt.plot(x, y_total, label=f"Time = {t}", color=color)

plt.title("Total Waves at Different Times")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# パラメータ設定
A = 1           # 振幅
c_values = [2, 4, 6, 8]  # 複数の位相速度
delta_c = 0.5   # 波速度の差
x = np.linspace(0, 50, 500) # x軸（距離）

# 8つの波動を合成
num_waves = 8

# 時間ステップと色
time_step = 5
colors = ['g', 'b', 'r', 'm']

plt.figure()

for c, color in zip(c_values, colors):
    y_total = np.zeros_like(x)
    for i in range(num_waves):
        c_i = c + i * delta_c
        y = A * np.sin(time_step - x / c_i)
        y_total += y
    
    plt.plot(x, y_total, label=f"c = {c}", color=color)

plt.title("Effect of Changing c on Group Velocity")
plt.legend()
plt.show()
